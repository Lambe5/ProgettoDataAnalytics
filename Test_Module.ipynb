# %%
import pandas as pd
import first_analysis

def load_df(path1, path2, path3):
    df1 = pd.read_csv(path1)
    df2 = pd.read_csv(path2)
    df3 = pd.read_csv(path3)
    return (df1, df2, df3)

# %%
(fnn_pca, fnn_scaled_no_outliers, tabNet_scaled) = load_df(
    "df_Res_fnn_PCA_no_outliers.csv", "df_Res_fnn_scaled_no_outliers.csv", "df_Res_tabnet_Scaled.csv")

# %%
fnn_scaled_no_outliers.sort_values(by='mse', ascending=True)
# Out:
#       Unnamed: 0  depth  hidden_size    lr  dropout_rate           mse  \
# 704          704      3          400  0.01           0.7  1.231863e+02
# 525          525      2          400  0.01           0.3  1.217399e+02
# 1053        1053      5          300  0.10           0.3  1.217294e+02
# 1242        1242      6          400  0.01           0.3  1.260047e+02
# 701          701      3          300  0.10           0.7  1.209160e+02
# ...          ...    ...          ...   ...           ...           ...
# 188          188      1            5  0.01           0.7  5.085081e+05
# 1268        1268      7            5  0.01           0.7  5.086603e+05
# 208          208      1           10  0.10           0.5  7.438058e+05
# 362          362      2            5  0.01           0.7  7.071091e+05
# 226          226      1           15  0.10           0.5  1.083988e+07
#
#               mae      mape            r2 activation_f
# 704      7.538131  0.003792     -0.107013         ReLU
# 525      7.542616  0.003793     -0.094015         Tanh
# 1053     7.542767  0.003794     -0.093921         ReLU
# 1242     7.543382  0.003795     -0.132340         ReLU
# 701      7.545567  0.003795     -0.086610      Sigmoid
# ...           ...       ...           ...          ...
# 188    713.019500  0.356793  -4568.704619      Sigmoid
# 1268   713.126400  0.356847  -4570.071960      Sigmoid
# 208    791.241640  0.395993  -6683.204780         ReLU
# 362    840.831800  0.420755  -6353.431653         ReLU
# 226   3164.463100  1.583640 -97411.480696         ReLU
#
# [1620 rows x 10 columns]

# %%
tabNet_scaled.sort_values(by='test_loss', ascending=True)

# %%
import pandas as pd
import numpy as np
import joblib  # o import pickle se hai usato pickle

# Passo 1: Carica il modello
model = joblib.load('./models2/knn_model_scaled_handeled_outliers.save')  # Sostituisci con 'pickle.load()' se usi pickle

# Passo 2: Carica i dati di test
X_test = np.load('./Datasets/Train_Test/Scaled/X_test_scaled.npy')  # Assumi che i dati di test siano in un file CSV

# Passo 3: Prepara i dati se necessario (e.g., scaling)
# (Dipende dalle trasformazioni che hai applicato durante l'addestramento)

# Passo 4: Fai previsioni
predictions = model.predict(X_test)

# Passo 5: Valuta le previsioni (opzionale)
# Se hai i target veri, puoi confrontare le previsioni con i target
y_test = pd.read_csv('./Datasets/Train_Test/y_test.csv')  # Carica i target veri se disponibili
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(y_test, predictions)
print(f"MAE: {mae}")

# Passo 6: Esporta o utilizza le previsioni
# Salva le previsioni in un file CSV
# Out:
# MAE: 6.974648217424616
